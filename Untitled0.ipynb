# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 KB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 16.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import numpy as np
from PIL import Image
import requests
from io import BytesIO
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
model = YOLO("yolov8n.pt") #load a pre-trained version of YOLOv8

# %%
response = requests.get("https://images.unsplash.com/photo-1600880292203-757bb62b4baf?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=2070&q=80")
image = Image.open(BytesIO(response.content)) #load an image from the internet and transform it into a numpy array
image = np.asarray(image)

# %%
#results = model.predict(image) #run the prediction on our image
# Out:
# 0: 448x640 2 persons, 3 cups, 2 chairs, 1 dining table, 1 laptop, 172.7ms
# Speed: 1.5ms preprocess, 172.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
results = model.track(source="vidtest.mp4", show=True, tracker="bytetrack.yaml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c1e878b49b4f> in <module>
# ----> 1 results = model.track("vidtest.mp4", show=True, tracker="bytetrack.yaml")
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/model.py in track(self, source, stream, **kwargs)
#     228         kwargs['conf'] = conf
#     229         kwargs['mode'] = 'track'
# --> 230         return self.predict(source=source, stream=stream, **kwargs)
#     231
#     232     @smart_inference_mode()
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ...
